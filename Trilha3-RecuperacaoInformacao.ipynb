# %% [markdown]
# <a href="https://colab.research.google.com/github/jnsoliveira/Atividades/blob/main/Trilha3-RecuperacaoInformacao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **LINKS**
#
# Github -
#
# GoogleColab -

# %% [markdown]
# # **RECUPERAÇÃO DA INFORMAÇÃO NA WEB E EM REDE SOCIAIS**
# **Atividade - Trilha 3**
#
# Agora que você aprendeu toda a história da World Wide Web e como raspar documentos HTML, chegou a sua vez de pôr em prática e demonstrar seu conhecimento.
#
# Escolha o assunto que achar mais pertinente e construa um robô de raspagem de tela, coletando todas as informações necessárias para seu projeto e estruturando em um ou mais arquivos de saída.
#
# Seu robô deverá raspar páginas de no mínimo dois tipos de documento diferentes, manipulando no mínimo 20 documentos distintos. Você deverá salvar o resultado em um arquivo CSV ou JSON.

# %% [markdown]
# # **BIBLIOTECAS**

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url_base = 'https://lista.mercadolivre.com.br/geladeira'

response = requests.get(url_base)

site = BeautifulSoup(response.text, 'html.parser')

produtos = site.findAll('div', attrs={'class': 'andes-card andes-card--flat andes-card--default ui-search-result ui-search-result--core andes-card--padding-default'})

resultados = []
for produto in produtos:
  titulo = produto.find('h2', attrs={'class':'ui-search-item__title'})
  link = produto.find('a', attrs={'class':'ui-search-link'})
  real= produto.find('span', attrs={'class':'price-tag-fraction'})
  cent= produto.find('span', attrs={'class':'price-tag-cents'})
  
  if (cent):
    preço = real.text + ',' + cent.text
  else:
    preço = real.text  

  row = {'Descrição': titulo, 'Preço': preço, 'Link': link['href']}
  resultados.append(row)

produtos_df = pd.DataFrame(resultados)
produtos_df.to_excel('Produtos.xlsx',index=False)
display(produtos_df)
# Out:
#                                             Descrição     Preço  \
# 0   [Geladeira inverter frost free Panasonic NR-BB...  5.699,92
# 1   [Geladeira inverter auto defrost Panasonic NR-...  3.499,58
# 2   [Geladeira Consul CRD37E branca com freezer 33...  2.079,25
# 3   [Geladeira inverter frost free Panasonic NR-BT...  4.599,58
# 4   [Geladeira frost free Panasonic NR-BT40 branca...  3.299,92
# 5   [Geladeira frost free Consul CRM43N branca com...  3.189,92
# 6   [Geladeira frost free Consul CRM39A branca com...  2.439,25
# 7   [Geladeira frost free Consul CRB36A branca com...  2.699,59
# 8        [Geladeira Electrolux RE31 branca 240L 127V]  1.959,40
# 9   [Geladeira frost free Brastemp BRE57A branca c...  5.109,58
# 10  [Geladeira frost free Brastemp BRO80A inox com...  6.596,68
# 11  [Geladeira frost free Consul CRM50H inox com f...  3.349,08
# 12  [Geladeira frost free Brastemp BRE57A inox com...  4.607,95
# 13  [Geladeira frost free Brastemp BRM44H inox com...  2.839,58
